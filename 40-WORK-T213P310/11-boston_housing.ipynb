# %% [markdown]
# #### 라이브러리 불러오기

# %%
import numpy as np
import tensorflow as tf
from datetime import datetime

# 회귀모델 평가 지표
from sklearn.metrics import mean_squared_error
# RMSE(Root Mean Squared Error) = np.sqrt(mse)
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.metrics import r2_score

from sklearn.model_selection import GridSearchCV

# 사용할 모델
from sklearn.linear_model import Lasso, Ridge, LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import ElasticNet
from xgboost import XGBRegressor
import lightgbm as lgb

# %% [markdown]
# #### 데이터 불러오기
# * 데이터는 `keras.datasets`에서 가져왔으며, numpy.ndarray로 되어 있음

# %%
(train_x, train_y), (test_x, test_y) = tf.keras.datasets.boston_housing.load_data()

# %%
train_x.shape, type(train_x)
# Out:
# ((404, 13), numpy.ndarray)

# %% [markdown]
# #### 공통변수

# %%
SEED = 1234

# %% [markdown]
# #### 평가함수

# %%
def evaluation_func(test_y, pred_y, verbose=1):
    mse = mean_squared_error(test_y, pred_y)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(test_y, pred_y)
    mape = mean_absolute_percentage_error(test_y, pred_y)
    
    if verbose != 0:
        print(f'MSE: {mse:.6f}, RMSE: {rmse:.6f}, MAE: {mae:.6f}, MAPE: {mape:.6f}')
        
    return mse, rmse, mae, mape

# %% [markdown]
# #### ML 라이브러리

# %% [markdown]
# ##### Lasso

# %%
model_l = Lasso().fit(train_x, train_y)
pred_l = model_l.predict(test_x)
_ = evaluation_func(test_y, pred_l)
# Out:
# MSE: 25.821651, RMSE: 5.081501, MAE: 3.405307, MAPE: 0.162639

# %% [markdown]
# ##### Ridge

# %%
model_r = Ridge().fit(train_x, train_y)
pred_r = model_r.predict(test_x)
_ = evaluation_func(test_y, pred_r)
# Out:
# MSE: 22.548159, RMSE: 4.748490, MAE: 3.402405, MAPE: 0.172457

# %% [markdown]
# ##### 기타 성능 지표

# %%
# 모델 예측성능 지표(모델이 데이터를 잘 설명하는지 여부[0~1])
# 0: 전혀 못함, 1: 잘 설명함
model_r.score(test_x, test_y)
# Out:
# 0.729131232028436

# %%
# score와 동일(높으면 좋음)
r2_score(test_y, pred_r)
# Out:
# 0.729131232028436

# %% [markdown]
# ##### KNeighborsRegressor

# %%
model_knr = KNeighborsRegressor().fit(train_x, train_y)
pred_knr = model_knr.predict(test_x)
_ = evaluation_func(test_y, pred_knr)
# Out:
# MSE: 36.969314, RMSE: 6.080240, MAE: 4.376275, MAPE: 0.215995

# %% [markdown]
# ##### DecisionTreeRegressor

# %%
model_dtr = DecisionTreeRegressor().fit(train_x, train_y)
pred_dtr = model_dtr.predict(test_x)
_ = evaluation_func(test_y, pred_dtr)
# Out:
# MSE: 22.069706, RMSE: 4.697841, MAE: 3.267647, MAPE: 0.174349

# %% [markdown]
# * GridSearchCV

# %%
# DecisionTreeRegressor 모델 생성
model_dtr = DecisionTreeRegressor(random_state=SEED)

# 튜닝할 하이퍼파라미터 범위 지정
param_grid_dtr = {
    'max_depth': [None, 5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search_dtr = GridSearchCV(
    model_dtr, param_grid_dtr, cv=5, scoring='neg_mean_squared_error'
).fit(train_x, train_y)

# 최적의 하이퍼파라미터와 성능 출력
best_params_dtr = grid_search_dtr.best_params_
print("Best Hyperparameters:", best_params_dtr)

# 최적의 모델로 예측
best_model_dtr = grid_search_dtr.best_estimator_
pred_dtr = best_model_dtr.predict(test_x)
_ = evaluation_func(test_y, pred_dtr)
# Out:
# Best Hyperparameters: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 2}
# MSE: 21.141087, RMSE: 4.597944, MAE: 3.256056, MAPE: 0.172123

# %% [markdown]
# ##### RandomForestRegressor

# %%
model_rfr = RandomForestRegressor(
    n_estimators=500, n_jobs=-1, random_state=SEED
)
model_rfr.fit(train_x, train_y)
# Out:
# RandomForestRegressor(n_estimators=500, n_jobs=-1, random_state=1234)

# %%
pred_y_rfr = model_rfr.predict(test_x)

# %%
_ = evaluation_func(test_y, pred_y_rfr)
# Out:
# MSE: 13.419559, RMSE: 3.663272, MAE: 2.414084, MAPE: 0.132021

# %% [markdown]
# * GridSearchCV를 이용한 하이퍼파라메터 튜닝

# %%
model_rfr = RandomForestRegressor(n_jobs=-1, random_state=SEED)

param_grid = {
    'n_estimators': [100, 500, 1000],
    'max_depth': [None, 10, 30, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search_rfr = GridSearchCV(
    model_rfr, param_grid, cv=5, scoring='neg_mean_squared_error'
)

_start = datetime.now()
grid_search_rfr.fit(train_x, train_y)
print(f'GridSearchCV 처리시간: {datetime.now()-_start}')

best_params = grid_search_rfr.best_params_
print(f'Best Hyperparameters: {best_params}')
model_rfr_best = grid_search_rfr.best_estimator_

pred_rfr_b = model_rfr_best.predict(test_x)
evaluation_func(test_y, pred_rfr_b)
# Out:
# GridSearchCV 처리시간: 0:19:37.644257
# Best Hyperparameters: {'max_depth': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1000}
# MSE: 13.512921, RMSE: 3.675992, MAE: 2.418914, MAPE: 0.132344
# (13.512920528039215, 3.67599245483981, 2.4189137254901882, 0.1323438394952828)

# %% [markdown]
# ##### GradientBoostingRegressor

# %%
model_gbr = GradientBoostingRegressor().fit(train_x, train_y)
pred_gbr = model_gbr.predict(test_x)
_ = evaluation_func(test_y, pred_gbr)
# Out:
# MSE: 12.679853, RMSE: 3.560878, MAE: 2.345200, MAPE: 0.130145

# %% [markdown]
# ##### ElasticNet

# %%
model_en = ElasticNet(
    alpha=0.1,          # 규제강도(0~inf), 
                        # 값이 클수록 규제가 강화되고 모델이 단순화됨
    l1_ratio=0.5,       # L1/L2 규제 균형조절, 0(L2만), 1(L1만) 사용
    random_state=SEED
).fit(train_x, train_y)
pred_en = model_en.predict(test_x)
_ = evaluation_func(test_y, pred_en)
# Out:
# MSE: 21.769895, RMSE: 4.665822, MAE: 3.333082, MAPE: 0.170267

# %% [markdown]
# ##### XGBRegressor

# %%
model_xgb = XGBRegressor(eta=0.01, n_estimators=100, n_jobs=-1).fit(train_x, train_y)

# %%
pred_xgb = model_xgb.predict(test_x)
_ = evaluation_func(test_y, pred_xgb)
# Out:
# MSE: 102.053371, RMSE: 10.102147, MAE: 8.885332, MAPE: 0.363386

# %%
model_xgb = XGBRegressor(
    objective="reg:squarederror",
    n_estimators=200,
    n_jobs=-1,
    max_depth=3,
    learning_rate=0.11,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
).fit(train_x, train_y)
pred_xgb = model_xgb.predict(test_x)
_ = evaluation_func(test_y, pred_xgb)
# Out:
# MSE: 12.260352, RMSE: 3.501479, MAE: 2.164824, MAPE: 0.117345

# %% [markdown]
# ##### LightGBM

# %%
# LightGBM 데이터셋 생성
train_ds_lgb = lgb.Dataset(train_x, label=train_y)
test_ds_lgb = lgb.Dataset(test_x, label=test_y, reference=train_ds_lgb)

# %%
# LightGBM 모델 설정
params = {
    "objective": "regression",
    "metric": "rmse",
    "boosting_type": "gbdt",    # 부스팅 알고리즘
                                # gbdt: Gradient Boosting Decision Tree
    "num_leaves": 31,           # 하나의 결정트리에서 사용하는 최대 잎(리프) 노드 수
                                # 크면 모델 복잡도가 증가하고, 적으면 모델이 간단해짐
    "learning_rate": 0.05,
    "feature_fraction": 0.9     # 모델 학습시 피처 샘플링 비율
                                # 일부만 사용해 과적합을 방지하고자 할 때 주로 사용
}

# %%
# 모델 훈련
num_round = 1000
bst = lgb.train(
    params, 
    train_ds_lgb, 
    num_round,      # num_round: GBDT에서 사용할 트리 갯 수
    valid_sets=[test_ds_lgb]
)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000668 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1021
# [LightGBM] [Info] Number of data points in the train set: 404, number of used features: 13
# [LightGBM] [Info] Start training from score 22.395050
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's rmse: 8.771
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's rmse: 8.41432
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's rmse: 8.07667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's rmse: 7.78076
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's rmse: 7.49969
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's rmse: 7.22148
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's rmse: 7.01511
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's rmse: 6.77446
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's rmse: 6.54845
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's rmse: 6.35881
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's rmse: 6.17107
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's rmse: 5.98606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's rmse: 5.82741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's rmse: 5.67726
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's rmse: 5.54277
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's rmse: 5.4138
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's rmse: 5.29538
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's rmse: 5.19542
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's rmse: 5.0967
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's rmse: 5.00488
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's rmse: 4.9114
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's rmse: 4.82809
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's rmse: 4.74814
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's rmse: 4.66074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's rmse: 4.59113
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's rmse: 4.52046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's rmse: 4.45534
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's rmse: 4.39352
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's rmse: 4.34024
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's rmse: 4.2892
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's rmse: 4.25223
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's rmse: 4.20686
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's rmse: 4.17915
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's rmse: 4.14144
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's rmse: 4.11374
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's rmse: 4.088
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid_0's rmse: 4.06507
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid_0's rmse: 4.03747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's rmse: 4.00856
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's rmse: 3.98784
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's rmse: 3.97365
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's rmse: 3.95652
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's rmse: 3.93751
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's rmse: 3.91259
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's rmse: 3.88505
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [46]	valid_0's rmse: 3.86129
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's rmse: 3.84109
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's rmse: 3.82144
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's rmse: 3.80525
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's rmse: 3.79268
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's rmse: 3.77483
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's rmse: 3.76126
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's rmse: 3.75186
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [54]	valid_0's rmse: 3.74534
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [55]	valid_0's rmse: 3.73019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [56]	valid_0's rmse: 3.71905
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [57]	valid_0's rmse: 3.70945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [58]	valid_0's rmse: 3.70116
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [59]	valid_0's rmse: 3.68301
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	valid_0's rmse: 3.67956
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [61]	valid_0's rmse: 3.66614
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [62]	valid_0's rmse: 3.65359
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [63]	valid_0's rmse: 3.64404
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [64]	valid_0's rmse: 3.63379
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [65]	valid_0's rmse: 3.62105
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [66]	valid_0's rmse: 3.60983
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [67]	valid_0's rmse: 3.60303
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [68]	valid_0's rmse: 3.59321
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [69]	valid_0's rmse: 3.59043
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	valid_0's rmse: 3.57819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [71]	valid_0's rmse: 3.57224
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [72]	valid_0's rmse: 3.56434
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [73]	valid_0's rmse: 3.55873
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [74]	valid_0's rmse: 3.55522
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [75]	valid_0's rmse: 3.54582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [76]	valid_0's rmse: 3.53908
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [77]	valid_0's rmse: 3.5321
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [78]	valid_0's rmse: 3.52193
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [79]	valid_0

# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [878]	valid_0's rmse: 3.45939
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [879]	valid_0's rmse: 3.45924
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [880]	valid_0's rmse: 3.45908
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [881]	valid_0's rmse: 3.45973
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [882]	valid_0's rmse: 3.45994
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [883]	valid_0's rmse: 3.46031
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [884]	valid_0's rmse: 3.46055
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [885]	valid_0's rmse: 3.46078
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [886]	valid_0's rmse: 3.46038
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [887]	valid_0's rmse: 3.46044
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [888]	valid_0's rmse: 3.46081
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [889]	valid_0's rmse: 3.46091
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [890]	valid_0's rmse: 3.46097
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [891]	valid_0's rmse: 3.4611
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [892]	valid_0's rmse: 3.46131
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [893]	valid_0's rmse: 3.46132
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [894]	valid_0's rmse: 3.46027
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [895]	valid_0's rmse: 3.46046
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [896]	valid_0's rmse: 3.4602
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [897]	valid_0's rmse: 3.46027
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [898]	valid_0's rmse: 3.46045
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [899]	valid_0's rmse: 3.46025
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [900]	valid_0's rmse: 3.46073
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [901]	valid_0's rmse: 3.46106
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [902]	valid_0's rmse: 3.46086
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [903]	valid_0's rmse: 3.46084
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [904]	valid_0's rmse: 3.46044
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [905]	valid_0's rmse: 3.45951
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [906]	valid_0's rmse: 3.46
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [907]	valid_0's rmse: 3.45997
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [908]	valid_0's rmse: 3.45981
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [909]	valid_0's rmse: 3.46005
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [910]	valid_0's rmse: 3.45977
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [911]	valid_0's rmse: 3.46019
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [912]	valid_0's rmse: 3.45999
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [913]	valid_0's rmse: 3.45966
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [914]	valid_0's rmse: 3.45934
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [915]	valid_0's rmse: 3.4595
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [916]	valid_0's rmse: 3.45951
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [917]	valid_0's rmse: 3.45938
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [918]	valid_0's rmse: 3.45967
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [919]	valid_0's rmse: 3.45922
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [920]	valid_0's rmse: 3.4591
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [921]	valid_0's rmse: 3.45929
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [922]	valid_0's rmse: 3.45908
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [923]	valid_0's rmse: 3.45932
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [924]	valid_0's rmse: 3.45947
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [925]	valid_0's rmse: 3.45981
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [926]	valid_0's rmse: 3.45977
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [927]	valid_0's rmse: 3.46016
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [928]	valid_0's rmse: 3.45984
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [929]	valid_0's rmse: 3.45964
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [930]	valid_0's rmse: 3.45911
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [931]	valid_0's rmse: 3.4593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [932]	valid_0's rmse: 3.45937
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [933]	valid_0's rmse: 3.45908
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [934]	valid_0's rmse: 3.45875
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [935]	valid_0's rmse: 3.45865
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [936]	valid_0's rmse: 3.45824
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [937]	valid_0's rmse: 3.45803
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [938]	valid_0's rmse: 3.45798
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [939]	valid_0's rmse: 3.45718
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [940]	valid_0's rmse: 3.45717
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [941]	valid_0's rmse: 3.45706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [942]	valid_0's rmse: 3.4577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [943]	valid_0's rmse: 3.45764
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [944]	valid_0's rmse: 3.45746
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [945]	valid_0's rmse: 3.45729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [946]	valid_0's rmse: 3.45745
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [947]	valid_0's rmse: 3.45727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [948]	valid_0's rmse: 3.45738
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [949]	valid_0's rmse: 3.45749
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [950]	valid_0's rmse: 3.45763
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [951]	valid_0's rmse: 3.4582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [952]	valid_0's rmse: 3.45798
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [953]	valid_0's rmse: 3.45819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [954]	valid_0's rmse: 3.45925
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [955]	valid_0's rmse: 3.45877
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [956]	valid_0's rmse: 3.45845
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [957]	valid_0's rmse: 3.45821
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [958]	valid_0's rmse: 3.45812
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [959]	valid_0's rmse: 3.45848
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [960]	valid_0's rmse: 3.45839
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [961]	valid_0's rmse: 3.45822
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [962]	valid_0's rmse: 3.45839
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [963]	valid_0's rmse: 3.45853
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [964]	valid_0's rmse: 3.45866
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [965]	valid_0's rmse: 3.45842
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [966]	valid_0's rmse: 3.45817
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [967]	valid_0's rmse: 3.45806
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [968]	valid_0's rmse: 3.45824
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [969]	valid_0's rmse: 3.45856
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [970]	valid_0's rmse: 3.4588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [971]	valid_0's rmse: 3.45858
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [972]	valid_0's rmse: 3.45856
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [973]	valid_0's rmse: 3.45864
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [974]	valid_0's rmse: 3.45844
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [975]	valid_0's rmse: 3.4586
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [976]	valid_0's rmse: 3.45886
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [977]	valid_0's rmse: 3.45886
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [978]	valid_0's rmse: 3.45895
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [979]	valid_0's rmse: 3.45918
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [980]	valid_0's rmse: 3.45902
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [981]	valid_0's rmse: 3.45932
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [982]	valid_0's rmse: 3.45928
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [983]	valid_0's rmse: 3.45967
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [984]	valid_0's rmse: 3.4596
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [985]	valid_0's rmse: 3.45949
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [986]	valid_0's rmse: 3.45985
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [987]	valid_0's rmse: 3.45914
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [988]	valid_0's rmse: 3.45909
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [989]	valid_0's rmse: 3.45923
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [990]	valid_0's rmse: 3.45948
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [991]	valid_0's rmse: 3.45936
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [992]	valid_0's rmse: 3.45979
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [993]	valid_0's rmse: 3.45994
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [994]	valid_0's rmse: 3.4599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [995]	valid_0's rmse: 3.46025
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [996]	valid_0's rmse: 3.46007
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [997]	valid_0's rmse: 3.46023
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [998]	valid_0's rmse: 3.46025
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [999]	valid_0's rmse: 3.46008
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1000]	valid_0's rmse: 3.45996

# %%
# 모델 평가
pred_y_lgb = bst.predict(test_x, num_iteration=bst.best_iteration)
_, _, _, _ = evaluation_func(test_y, pred_y_lgb)
# Out:
# MSE: 11.971329, RMSE: 3.459961, MAE: 2.205423, MAPE: 0.118909

# %% [markdown]
# #### DL 라이브러리
