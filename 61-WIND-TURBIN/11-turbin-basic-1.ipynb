# %% [markdown]
# #### 라이브러리 불러오기

# %%
import os
import folium
import numpy as np
import pandas as pd
import geopandas as gpd
import tensorflow as tf
import requests

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

from xgboost import XGBRegressor
from model_evaluation import regression_evaluation, f_importances, user_mape
# Out:
# 2023-08-28 18:54:49.220280: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# #### 설정

# %% [markdown]
# ##### VWorld

# %%
VW_KEY_PATH = os.path.join(os.path.expanduser('~'), 'projects', 'vworld_key.txt')
with open(VW_KEY_PATH, 'r') as _key_file:
    _vw_lines = _key_file.readlines()
VW_KEY = _vw_lines[0].replace('\n', '')

# %%
VW_TILE_TYPE = 'png'
VW_ATTR = 'Vworld'

# %% [markdown]
# ##### 차트 한글

# %%
import platform

_os_name = platform.system()

# font_path는 사용할 폰트에 따라 변경하면 됨
_font_path = 'c:/Windows/Fonts/malgun.ttf' if _os_name=='Windows' \
    else '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
_font_family = fm.FontProperties(fname=_font_path).get_name()

# font 설정
plt.rcParams['font.family'] = _font_family

# 폰트캐시까지 삭제 후 한글폰트가 사용될 수 있도록 캐시 삭제
# --> 이렇게 해야 비로소 한글이 표현되는 경우가 많음
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = [_font_family]

_fe = fm.FontEntry(
    fname='/usr/share/fonts/truetype/nanum/NanumGothic.ttf',
    name='NanumGothic'
)
fm.fontManager.ttflist.insert(0, _fe)

# %% [markdown]
# #### 지도에 터빈위치 표시

# %%
turbin_info = {
    'a': { 'lat': 35.486483143070764, 'lon': 126.34213114581526, 'name': 'A'},
    'b': { 'lat': 35.48131840227845,  'lon': 126.33507818977857, 'name': 'B'},
    'c': { 'lat': 35.476172884715325, 'lon': 126.32890690366085, 'name': 'C'},
    'd': { 'lat': 35.471026994051186, 'lon': 126.32273651737738, 'name': 'D'},
}

# %%
VW_LATS = [info['lat'] for info in turbin_info.values()]
VW_LONS = [info['lon'] for info in turbin_info.values()]
VW_MAP_CENTER = [(min(VW_LATS)+max(VW_LATS))/2, (min(VW_LONS)+max(VW_LONS))/2]

# %%
VW_LAYER = 'Base'
VW_TILES_URL = \
    f'http://api.vworld.kr/req/wmts/1.0.0/' \
    f'{VW_KEY}/{VW_LAYER}/{{z}}/{{y}}/{{x}}.{VW_TILE_TYPE}'

# %%
base_map = folium.Map(
    location=VW_MAP_CENTER, zoom_start=12,
    tiles=VW_TILES_URL, attr=VW_ATTR
)

for _, _value in turbin_info.items():
    folium.Marker(
        location=[_value['lat'], _value['lon']],
        popup=f'{_value["name"]}-Turbin',
    ).add_to(base_map)

base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8fdb077c8aaf7d2e7898df27522b8108 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8fdb077c8aaf7d2e7898df27522b8108&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8fdb077c8aaf7d2e7898df27522b8108 = L.map(
#                 &quot;map_8fdb077c8aaf7d2e7898df27522b8108&quot;,
#                 {
#                     center: [35.47875506856097, 126.33243383159632],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_453be31a38ede1869b9c69cdada9e361 = L.tileLayer(
#                 &quot;http://api.vworld.kr/req/wmts/1.0.0/AC38C527-013B-3078-A053-6DD7FB7DF661/Base/{z}/{y}/{x}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Vworld&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8fdb077c8aaf7d2e7898df27522b8108);
#
#
#             var marker_f3f7b2f49aa7f28db82243282e9407d8 = L.marker(
#                 [35.486483143070764, 126.34213114581526],
#                 {}
#             ).addTo(map_8fdb077c8aaf7d2e7898df27522b8108);
#
#
#         var popup_00c8ada259eb9b5a669e3ca1379ab912 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e8a319917972180524b8bfa8dc1b695e = $(`&lt;div id=&quot;html_e8a319917972180524b8bfa8dc1b695e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A-Turbin&lt;/div&gt;`)[0];
#                 popup_00c8ada259eb9b5a669e3ca1379ab912.setContent(html_e8a319917972180524b8bfa8dc1b695e);
#
#
#
#         marker_f3f7b2f49aa7f28db82243282e9407d8.bindPopup(popup_00c8ada259eb9b5a669e3ca1379ab912)
#         ;
#
#
#
#
#             var marker_abea480cf6667c30e2d782acde793264 = L.marker(
#                 [35.48131840227845, 126.33507818977857],
#                 {}
#             ).addTo(map_8fdb077c8aaf7d2e7898df27522b8108);
#
#
#         var popup_5dc93c552edf61144a3001e2b583f597 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dac14ffa999b16d911ea7ccd984a8437 = $(`&lt;div id=&quot;html_dac14ffa999b16d911ea7ccd984a8437&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;B-Turbin&lt;/div&gt;`)[0];
#                 popup_5dc93c552edf61144a3001e2b583f597.setContent(html_dac14ffa999b16d911ea7ccd984a8437);
#
#
#
#         marker_abea480cf6667c30e2d782acde793264.bindPopup(popup_5dc93c552edf61144a3001e2b583f597)
#         ;
#
#
#
#
#             var marker_6d8fedab7666cd57bf2f4bbefd97ebfd = L.marker(
#                 [35.476172884715325, 126.32890690366085],
#                 {}
#             ).addTo(map_8fdb077c8aaf7d2e7898df27522b8108);
#
#
#         var popup_58a34eb5eccc64960544091ee6dbb39c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_136f4ada620a9080dc692495ef105114 = $(`&lt;div id=&quot;html_136f4ada620a9080dc692495ef105114&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;C-Turbin&lt;/div&gt;`)[0];
#                 popup_58a34eb5eccc64960544091ee6dbb39c.setContent(html_136f4ada620a9080dc692495ef105114);
#
#
#
#         marker_6d8fedab7666cd57bf2f4bbefd97ebfd.bindPopup(popup_58a34eb5eccc64960544091ee6dbb39c)
#         ;
#
#
#
#
#             var marker_3abf20adac6ffdf4ff354bce2c6d33bb = L.marker(
#                 [35.471026994051186, 126.32273651737738],
#                 {}
#             ).addTo(map_8fdb077c8aaf7d2e7898df27522b8108);
#
#
#         var popup_05f52a8a5042846dc7b9d3137d35e033 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a16425814a0e2366e0cbf9f3c72deac = $(`&lt;div id=&quot;html_8a16425814a0e2366e0cbf9f3c72deac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;D-Turbin&lt;/div&gt;`)[0];
#                 popup_05f52a8a5042846dc7b9d3137d35e033.setContent(html_8a16425814a0e2366e0cbf9f3c72deac);
#
#
#
#         marker_3abf20adac6ffdf4ff354bce2c6d33bb.bindPopup(popup_05f52a8a5042846dc7b9d3137d35e033)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### 데이터 불러오기

# %%
_PATH_BASE = os.path.join(os.getcwd(), 'data', '41-turbin')
get_path = lambda turbin: os.path.join(_PATH_BASE, f'{turbin}_turbin.csv')

# %%
df_a = pd.read_csv(get_path('a'))
df_b = pd.read_csv(get_path('b'))
df_c = pd.read_csv(get_path('c'))
df_d = pd.read_csv(get_path('d'))

# %% [markdown]
# #### 데이터 확인

# %%
# 결측치 확인
df_a.isna().sum()       

# 없음: 결측치는 -1로 들어온것 같음
# Out:
# TURBINE_TIME    0
# WIND_SPEED      0
# WIND_DIR        0
# ACTIVE_POWER    0
# month           0
# hour            0
# dtype: int64

# %%
# 음수인 row 갯 수 확인
non_value_counts = (df_a.drop('TURBINE_TIME', axis=1) < 0).sum()

# 풍속이 음수인 갯 수: 17540, 이건 모두 NaN(-1)으로 볼 수 있음
# 풍향이 음수인 갯 수: 20088, 거의 모든 데이터, 풍향은 음수일 수도 있음
# 발전량이 음수인 갯 수: 17540, 풍속과 동일한걸 보면 같이 NaN(-1) 처리하면 될듯

# %%
target_col = 'ACTIVE_POWER'

# %%
df_a_nn = df_a[df_a[target_col] != -1]

# %%
df_b_nn = df_b[df_b[target_col] != -1]
df_c_nn = df_c[df_c[target_col] != -1]
df_d_nn = df_d[df_d[target_col] != -1]

# %% [markdown]
# ##### 풍속 vs 발전량 차트

# %%
plt.figure(figsize=(12,6))
plt.plot(df_b['TURBINE_TIME'][:1000], df_b[target_col][:1000])
plt.plot(df_b['TURBINE_TIME'][:1000], df_b['WIND_SPEED'][:1000]*100)
plt.xlabel('일자')
plt.ylabel('발전량')
plt.xticks(df_b['TURBINE_TIME'][:1000:100], rotation=45)
plt.title('풍속 vs 발전량')
plt.tight_layout()
plt.show()

# %%
df_b[target_col].max()
# Out:
# 3092.2000000000003

# %%
df_b_1500 = df_b[df_b[target_col]>1500]
unique_values = df_b_1500['ACTIVE_POWER'].unique()
unique_values.sort()

x_ticks = range(len(unique_values))
plt.figure(figsize=(12,6))
plt.bar(x_ticks, unique_values)
# plt.xticks(x_ticks, unique_values)
plt.xlabel('일련번호')
plt.ylabel('발전량')
plt.title('최대 발전량을 확인하기 위한 차트')
plt.show()

# %%
unique_values[-15:]
# Out:
# array([3054.68333333, 3054.72333333, 3054.96833333, 3055.06833333,
#        3055.2375    , 3055.7490566 , 3055.94545455, 3056.65853659,
#        3056.7969697 , 3058.59111111, 3058.59444444, 3059.548     ,
#        3060.93571429, 3074.85      , 3092.2       ])
