# %% [markdown]
# #### 개요
# * 데이터가 가장 많은 b-turbin을 이용해 처리

# %% [markdown]
# #### 라이브러리 불러오기

# %%
import os
import numpy as np
import pandas as pd

from datetime import datetime, timedelta

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Flatten, Dropout, Conv2D

from model_evaluation import regression_evaluation
from xgboost import XGBRegressor

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns
# Out:
# 2023-08-29 10:09:42.775853: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# #### 차트 한글설정

# %%
import platform

_os_name = platform.system()

# font_path는 사용할 폰트에 따라 변경하면 됨
_font_path = 'c:/Windows/Fonts/malgun.ttf' if _os_name=='Windows' \
    else '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
_font_family = fm.FontProperties(fname=_font_path).get_name()

# font 설정
plt.rcParams['font.family'] = _font_family

# 폰트캐시까지 삭제 후 한글폰트가 사용될 수 있도록 캐시 삭제
# --> 이렇게 해야 비로소 한글이 표현되는 경우가 많음
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = [_font_family]

_fe = fm.FontEntry(
    fname='/usr/share/fonts/truetype/nanum/NanumGothic.ttf',
    name='NanumGothic'
)
fm.fontManager.ttflist.insert(0, _fe)

# %% [markdown]
# #### 데이터 불러오기

# %%
_PATH_BASE = os.path.join(os.getcwd(), 'data', '41-turbin')
get_path = lambda turbin: os.path.join(_PATH_BASE, f'{turbin}_turbin.csv')

# %%
df_data = pd.read_csv(get_path('b'))

# %% [markdown]
# ##### 하루 단위가 안되는 row 삭제

# %%
# 처음 2개와 마지막 4개
df_data = df_data.iloc[2:-4]

# %%
# 기존 인덱스를 컬럼으로 변경하고 새 인덱스를 생성함
df_data.reset_index(inplace=True)
# 기존 인덱스 제거
df_data.drop('index', axis=1, inplace=True)

# %% [markdown]
# * 백업

# %%
df_data_back = df_data.copy()

# %% [markdown]
# #### 데이터 확인

# %% [markdown]
# ##### 빠진로우 찾기

# %%
# 시간단위 데이터셋인데 시간단위가 빠진 로우가 있는지 확인
_datetime_fmt = '%Y-%m-%d %H:%M:%S'
_dt_start = df_data['TURBINE_TIME'].min()
_dt_end = df_data['TURBINE_TIME'].max()
dt_start = datetime.strptime(_dt_start, _datetime_fmt)
dt_end = datetime.strptime(_dt_end, _datetime_fmt)
_time_interval = timedelta(hours=1)
total_row_counts = int((dt_end - dt_start) / _time_interval) + 1

total_row_counts, df_data.shape

# (22320, (22320, 6))
# 다행이 시간단위로 모든 row가 존재함(NaN값(-1)은 존재)
# Out:
# (22320, (22320, 6))

# %%
# 목표 컬럼 지정
target_col = 'ACTIVE_POWER'

# %% [markdown]
# #### 데이터 확인

# %%
# 통계값 확인
desc = df_data.describe().T

# %%
# 3/4분위값 추출
target_wind_speed = desc[desc.index == 'WIND_SPEED']['75%'][0]
df_data_wind_3 = df_data[df_data['WIND_SPEED']>target_wind_speed]

# %%
_s_bin, _e_bin, _step, _weight = 0, 500, 24, 200
_e_bin = min(_e_bin, df_data_wind_3.shape[0])

# %%
plt.figure(figsize=(12,6))

plt.plot(
    df_data_wind_3['TURBINE_TIME'][_s_bin:_e_bin], 
    df_data_wind_3[target_col][_s_bin:_e_bin],
    label='발전량'
)
plt.plot(
    df_data_wind_3['TURBINE_TIME'][_s_bin:_e_bin], 
    df_data_wind_3['WIND_SPEED'][_s_bin:_e_bin]*_weight,
    label='풍속'
)
plt.xlabel('일시')
plt.ylabel('발전량/풍속')
plt.xticks(df_data_wind_3['TURBINE_TIME'][_s_bin:_e_bin:_step], rotation=45)
plt.title('발전량 vs 풍속')
plt.legend()
plt.show()

# %%
df_data_wind_3['rate'] = (df_data_wind_3[target_col]+1e-10)/df_data_wind_3['WIND_SPEED']

# %%
desc_wind_3 = df_data_wind_3['rate'].describe()

# %%
desc_wind_3['25%']
# Out:
# 126.07012986176765

# %%
df_data_wind_3[df_data_wind_3['rate']>desc_wind_3['75%']]
# Out:
#               TURBINE_TIME  WIND_SPEED  WIND_DIR  ACTIVE_POWER  month  hour  \
# 123    2020-01-21 03:00:00    8.428333  1.605000   2143.838333      1     3
# 124    2020-01-21 04:00:00    9.170000  0.645000   2687.820000      1     4
# 125    2020-01-21 05:00:00    8.468333 -1.271667   2315.711667      1     5
# 449    2020-02-03 17:00:00    8.725424  2.281356   2457.938983      2    17
# 450    2020-02-03 18:00:00    7.906667 -1.001667   1961.556667      2    18
# ...                    ...         ...       ...           ...    ...   ...
# 22304  2022-08-02 08:00:00    9.476271  0.308475   2411.740678      8     8
# 22305  2022-08-02 09:00:00    9.780000  2.003333   2534.266667      8     9
# 22306  2022-08-02 10:00:00    9.596667  6.198333   2422.135000      8    10
# 22307  2022-08-02 11:00:00    9.533333  4.700000   2339.940000      8    11
# 22311  2022-08-02 15:00:00    9.431667  2.973333   2327.835000      8    15
#
#              rate
# 123    254.360886
# 124    293.110142
# 125    273.455422
# 449    281.698524
# 450    248.088954
# ...           ...
# 22304  254.503130
# 22305  259.127471
# 22306  252.393366
# 22307  245.448252
# 22311  246.810567
#
# [1395 rows x 7 columns]

# %%
# 바람의 세기가 셀 때 일부러 터빈을 종료하지는 않음
df_data_wind_3[df_data_wind_3['WIND_SPEED']>10].sort_values(by=target_col)[:10]
# Out:
#               TURBINE_TIME  WIND_SPEED  WIND_DIR  ACTIVE_POWER  month  hour  \
# 14080  2021-08-24 16:00:00   10.234146 -3.704878   2352.253659      8    16
# 12839  2021-07-03 23:00:00   10.643333  3.220000   2405.403333      7    23
# 4850   2020-08-05 02:00:00   10.045000  3.190000   2414.545000      8     2
# 14013  2021-08-21 21:00:00   11.265455  1.840000   2457.847273      8    21
# 11542  2021-05-10 22:00:00   10.493333  4.940000   2471.263333      5    22
# 21522  2022-06-30 18:00:00   10.038333  2.600000   2496.678333      6    18
# 16498  2021-12-03 10:00:00   10.288333  0.968333   2518.721667     12    10
# 11495  2021-05-08 23:00:00   10.213333  2.353333   2532.555000      5    23
# 5102   2020-08-15 14:00:00   10.013333  4.898333   2553.055000      8    14
# 10494  2021-03-28 06:00:00   10.043333 -5.378333   2568.868333      3     6
#
#              rate
# 14080  229.843661
# 12839  226.000940
# 4850   240.372822
# 14013  218.175597
# 11542  235.507942
# 21522  248.714428
# 16498  244.813381
# 11495  247.965568
# 5102   254.965546
# 10494  255.778460

# %%
# 상관행렬 계산
corr_matrix = df_data_wind_3[[target_col, 'WIND_SPEED', 'WIND_DIR']].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Heatmap')
plt.show()

# %%
sns.set(font_scale=1.5)
hm = sns.heatmap(
    corr_matrix.values,
    cbar=True, annot=True, square=True, fmt='.2f',
    annot_kws={'size': 15},
    yticklabels = [target_col, 'WIND_SPEED', 'WIND_DIR'],
    xticklabels = [target_col, 'WIND_SPEED', 'WIND_DIR']
)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.pairplot(df_data_wind_3[[target_col, 'WIND_SPEED', 'WIND_DIR']])
plt.show()
# Out:
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(8,6))
sns.pairplot(df_data[[target_col, 'WIND_SPEED', 'WIND_DIR']])
plt.show()
# Out:
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### 데이터 전처리

# %% [markdown]
# ##### 결측치 처리

# %%
# 결측치 처리를 위해 목표컬럼인 'ACTIVE_POWER'값이 -1인 row의 풍향/풍속/발전량을 NaN으로 변경
# 참고로, 풍속과 발전량이 -1인 로우수가 같으니 발전량을 선택한것임(풍향은 -1이 나올수 있음)

# 풍속, 발전량은 음수가 올 수 없으므로 이렇게 NaN값 확인
non_value_counts = (df_data.drop('TURBINE_TIME', axis=1) < 0).sum()
non_value_counts

# 풍속과 발전량의 값이 음수(NaN)인 로우가 같음
# Out:
# WIND_SPEED       9353
# WIND_DIR        15108
# ACTIVE_POWER     9353
# month               0
# hour                0
# dtype: int64

# %%
# 발전량이 음수인 컬럼의 풍향/풍속/발전량 값을 NaN으로 변경
df_data.loc[df_data[target_col] < 0, ['WIND_SPEED', 'WIND_DIR']+[target_col]] = np.nan

# %%
# 혹시 모르니 풍향이 음수인 경우 풍속과 발전량 값 확인
df_data[df_data['WIND_DIR']<0].head()
# Out:
#           TURBINE_TIME  WIND_SPEED  WIND_DIR  ACTIVE_POWER  month  hour
# 0  2020-01-16 00:00:00    4.355769 -1.425000    273.946154      1     0
# 1  2020-01-16 01:00:00    4.041667 -0.678333    214.488333      1     1
# 4  2020-01-16 04:00:00    6.335000 -1.238333    956.623333      1     4
# 6  2020-01-16 06:00:00    7.245000 -0.723333   1493.048333      1     6
# 7  2020-01-16 07:00:00    5.398333 -0.260000    628.846667      1     7

# %%
# 시계열성값을 이용한 결측치 처리
df_data = df_data.interpolate()

# %% [markdown]
# * 결측치 처리 결과 시각화

# %%
plt.figure(figsize=(12,12))

plt.subplot(2,1,1)
plt.plot(df_data['TURBINE_TIME'][-200:], df_data[target_col][-200:])
plt.plot(df_data_back['TURBINE_TIME'][-200:], df_data_back[target_col][-200:])
plt.xlabel('일시')
plt.ylabel('발전량')
plt.xticks(df_data['TURBINE_TIME'][-200::24], rotation=45)
plt.title('발전량비교 실측값 vs 결측치처리값')

plt.subplot(2,1,2)
plt.plot(df_data['TURBINE_TIME'][-200:], df_data['WIND_SPEED'][-200:])
plt.plot(df_data_back['TURBINE_TIME'][-200:], df_data_back['WIND_SPEED'][-200:])
plt.xlabel('일시')
plt.ylabel('풍속')
plt.xticks(df_data['TURBINE_TIME'][-200::24], rotation=45)
plt.title('풍속비교 실측값 vs 결측치처리값')

plt.tight_layout()
plt.show()

# 풍속이 2이하면 발전량은 0이네
# Out:
# /tmp/ipykernel_10272/3316922510.py:19: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_10272/3316922510.py:19: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_10272/3316922510.py:19: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_10272/3316922510.py:19: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_10272/3316922510.py:19: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_10272/3316922510.py:19: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_10272/3316922510.py:19: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_10272/3316922510.py:19: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_10272/3316922510.py:19: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_10272/3316922510.py:19: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_10272/3316922510.py:19: UserWarning: Glyph 44208 (\N{HANGUL SYLLABLE GYEOL}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_10272/3316922510.py:19: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_10272/3316922510.py:19: UserWarning: Glyph 52376 (\N{HANGUL SYLLABLE CEO}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_10272/3316922510.py:19: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_10272/3316922510.py:19: UserWarning: Glyph 54413 (\N{HANGUL SYLLABLE PUNG}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_10272/3316922510.py:19: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from current font.
#   plt.tight_layout()
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51068 (\N{HANGUL SYLLABLE IL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48156 (\N{HANGUL SYLLABLE BAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51204 (\N{HANGUL SYLLABLE JEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47049 (\N{HANGUL SYLLABLE RYANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 48708 (\N{HANGUL SYLLABLE BI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44368 (\N{HANGUL SYLLABLE GYO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49892 (\N{HANGUL SYLLABLE SIL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44050 (\N{HANGUL SYLLABLE GABS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44208 (\N{HANGUL SYLLABLE GYEOL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52824 (\N{HANGUL SYLLABLE CI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 52376 (\N{HANGUL SYLLABLE CEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54413 (\N{HANGUL SYLLABLE PUNG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/freeman/anaconda3/envs/t213p310/lib/python3.10/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49549 (\N{HANGUL SYLLABLE SOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### 시간데이터 컬럼 추가

# %%
df_data['TURBINE_TIME'] = pd.to_datetime(df_data['TURBINE_TIME'])
df_data['day'] = df_data['TURBINE_TIME'].dt.day
df_data['dayofyear'] = df_data['TURBINE_TIME'].dt.dayofyear

# 컬럼을 다 추가했으니 'TURBINE_TIME'을 인덱스로 변경
df_data = df_data.set_index('TURBINE_TIME')

# %% [markdown]
# #### 시험데이터 찾기

# %%
# 뒤에서부터 발전량이 처음으로 -1이 나오는 인덱스를 구해 그 이후 데이터를 시험데이터로 활용
start_test_idx = df_data_back[target_col][::-1][df_data_back[target_col][::-1]==-1].index[0]

# 원래값은 22222인데 앞에 2개 row을 지웠기에 22220, 전체는 6개 줄어듬
# 22320 - 22220 = 100개(시험데이터로 충분함)

# %% [markdown]
# #### 데이터 백업2

# %%
df_data_back2 = df_data.copy()

# %% [markdown]
# #### 모델링 1차

# %%
WINDOW_SIZE = 48

# %%
X_data = df_data.drop(target_col, axis=1)
y_data = df_data[target_col]

# %%
scaler = MinMaxScaler()
X_data_array = scaler.fit_transform(X_data)
y_data_array = y_data.values

# %%
X_data_win = []
y_data_win = []
for i in range(len(X_data_array) - WINDOW_SIZE):
    X_data_win.append(X_data_array[i:i+WINDOW_SIZE, :])
    y_data_win.append(y_data_array[i+WINDOW_SIZE])
X_data_win = np.array(X_data_win)
y_data_win = np.array(y_data_win)

# %%
# 시험데이터로 뒤에서 96개 추출(4일자 데이터 24*4)
X_train, X_test = X_data_win[:-96, :], X_data_win[-96:, :]
y_train, y_test = y_data_win[:-96], y_data_win[-96:]

# %%
X_train_f = np.mean(X_train, axis=1)
X_test_f = np.mean(X_test, axis=1)

# %%
model_xgb = XGBRegressor(
    objective="reg:squarederror",
    n_estimators=100,
    n_jobs=-1,
    max_depth=3,
    learning_rate=0.11,
    subsample=0.9,
    colsample_bytree=0.8,
    random_state=1234
).fit(X_train_f, y_train)

pred_xgb = model_xgb.predict(X_test_f)
_ = regression_evaluation(y_test, pred_xgb)
# Out:
# R2_SCORE: 0.166646, MAPE2: 46.266506, MSE: 545783.036113, RMSE: 738.771302, MAPE: 0.771107, MAE: 538.224875

# %%
for t, p in zip(y_test, pred_xgb):
    print(f'{t:>15.6}, {p:>15.6}')
# Out:
#         28.8316,         326.417
#         79.5117,         326.417
#         322.817,         326.417
#         632.879,         326.417
#         661.581,         326.417
#         326.385,         358.871
#         98.0356,         370.755
#         49.4818,         370.755
#         76.7065,          347.08
#         106.125,          347.08
#         173.251,          347.08
#         114.736,         350.644
#         70.7596,         350.644
#           78.81,         350.644
#         132.332,         350.644
#         264.818,         350.644
#         261.264,         350.644
#         986.228,          381.25
#         569.346,          381.25
#         699.811,         427.069
#         461.567,         377.078
#         680.402,         377.078
#         420.532,         393.773
#         466.657,         400.108
#         468.232,         400.108
#          247.87,         400.108
#         298.928,         400.108
#           397.5,         400.108
#         433.158,         387.806
#         402.973,         387.806
#         732.637,          383.31
#         589.638,         402.206
#         340.913,         412.173
#         256.249,         463.899
#         623.646,         463.899
#         613.815,         399.807
#         763.073,          437.87
#         1157.44,         388.908
#         886.387,         396.183
#         639.046,         433.214
#         723.307,         381.488
#         240.337,         433.214
#         482.592,         385.984
#         494.655,         381.686
#         569.978,         381.686
#          869.17,         381.686
#         943.648,         407.456
#         1444.39,         467.971
#         1549.98,         473.755
#         1758.82,         554.336
#         2265.69,         626.898
#         1903.14,          647.21
#         1576.85,          647.21
#         2059.48,         676.585
#         1957.85,         735.978
#         2466.55,         796.903
#         1227.14,          835.13
#         706.427,          835.13
#         2140.91,         826.733
#         1432.57,         891.785
#         1375.34,         919.786
#         1328.52,         903.274
#         1432.63,         894.926
#         962.908,         894.926
#         1021.25,         894.926
#         1379.12,         894.926
#         1211.52,         905.126
#         859.448,         905.126
#         1895.47,         894.926
#         1665.02,         894.926
#         1157.67,         894.926
#         1378.33,         905.126
#         1468.01,         904.312
#         1268.46,          949.73
#         916.312,          949.73
#         2208.79,          1010.3
#         3038.45,         997.425
#         2981.64,         997.425
#         2763.16,         1081.09
#          2865.6,         1081.09
#         2411.74,         1064.97
#         2534.27,         1079.34
#         2422.14,         1106.48
#         2339.94,         1106.48
#         2095.89,         1196.48
#         1864.54,         1196.48
#         2028.38,         1196.48
#         2327.84,         1246.49
#         1969.08,         1246.49
#         2025.17,         1246.49
#         1938.48,         1246.49
#         1923.57,         1269.93
#         1989.09,         1338.83
#         1594.87,         1338.83
#         1383.29,         1295.31
#         1455.34,         1301.37

# %%
# model = tf.keras.Sequential([
#     Bidirectional(LSTM(units=50, activation='relu', return_sequences=True), input_shape=X_train.shape[1:]),
#     Bidirectional(LSTM(units=50, activation='relu')),
#     Dense(1)
# ])

# model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# model.fit(X_train, y_train, epochs=10, batch_size=32)

# %%
# model_cnn = tf.keras.Sequential([
#     # 여기도 차원이 너무 적어 보통 (3,3)을 하는데 (1,1)로 사용
#     Conv2D(32, (1,1), activation='relu', input_shape=(X_train.shape[1:])),
#     # MaxPooling2D((2,2)),    # 입력데이터의 차원이 너무적어(13*1*1) 이 부분은 전부 생략함
#     Conv2D(64, (1,1), activation='relu'),
#     # MaxPooling2D((2,2)),
#     Conv2D(128, (1,1), activation='relu'),
#     # MaxPooling2D((2,2)),
#     Flatten(),
#     Dense(64, activation='relu'),
#     Dense(32, activation='relu'),
#     Dense(1)
# ])
# model_cnn.compile(
#     optimizer='adam',
#     loss='mean_squared_error',
#     metrics=['mae']
# )
# model_cnn.summary()

# %%
# model_cnn.fit(X_train, y_train, epochs=10, batch_size=32)

# %%
# pred_cnn = model_cnn.predict(X_test).reshape(-1)

# %%
# regression_evaluation(y_test, pred_cnn)

# %%
# for t, p in zip(y_test, pred):
#     print(f'{t:>15.6}, {p:>15.6}')
